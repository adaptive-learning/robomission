# %% [markdown]
# # Data

# %%
import pandas as pd

# %%
path = '../.server/media/exports/robomission-2017-11-16/{entity}.csv'
load_entity = lambda name: pd.read_csv(path.format(entity=name), index_col='id')

# %% [markdown]
# ## Data Description

# %%
load_entity('tasks').head()
# Out:
#                 name            level  \
# id
# 1   colorful-flowers          if-else
# 2   dont-forget-shot            world
# 3      triple-slalom  final-challenge
# 4      wormhole-demo            world
# 5            cross-2  final-challenge
#
#                                               setting  \
# id
# 1   {"fields": [[["b", []], ["b", []], ["b", []], ...
# 2   {"fields": [[["b", []], ["b", []], ["b", []], ...
# 3   {"fields": [[["b", []], ["b", []], ["b", []], ...
# 4   {"fields": [[["b", []], ["b", []], ["b", []], ...
# 5   {"fields": [[["b", []], ["b", []], ["b", []], ...
#
#                                              solution
# id
# 1   {"head": "start", "body": [{"statement": {"hea...
# 2   {"head": "start", "body": [{"statement": {"hea...
# 3   {"head": "start", "body": [{"statement": {"hea...
# 4   {"head": "start", "body": [{"statement": {"hea...
# 5   {"head": "start", "body": [{"statement": {"hea...

# %%
load_entity('levels')
# Out:
#     level             name  credits            toolbox  \
# id
# 1       1            moves        6                fly
# 2       2            world       25              shoot
# 3       3           repeat       40             repeat
# 4       4            while       60              while
# 5       5            loops      100              loops
# 6       6               if      150           loops+if
# 7       7        comparing      200  loops+if+position
# 8       8          if-else      300      loops+if+else
# 9       9  final-challenge     1000           complete
#
#                                                 tasks
# id
# 1   ['turning-right-and-left', 'three-steps-forwar...
# 2   ['dont-forget-shot', 'wormhole-demo', 'shootin...
# 3   ['find-the-path', 'diamonds-in-meteoroid-cloud...
# 4   ['zig-zag', 'yellow-hint', 'direct-flight-ahea...
# 5   ['zig-zag-plus', 'big-slalom', 'color-slalom',...
# 6   ['diamonds-with-signals', 'two-diamonds', 'fol...
# 7   ['diamond-lines', 'slalom-position-testing', '...
# 8   ['colorful-flowers', 'narrow-passage', 'diamon...
# 9   ['triple-slalom', 'cross-2', 'diagonal-diamond...

# %%
load_entity('toolboxes')
# Out:
#                  name                                             blocks
# id
# 1                 fly                                            ['fly']
# 2               shoot                                   ['fly', 'shoot']
# 3              repeat                         ['fly', 'shoot', 'repeat']
# 4               while                 ['fly', 'shoot', 'while', 'color']
# 5               loops       ['fly', 'shoot', 'repeat', 'while', 'color']
# 6            loops+if  ['fly', 'shoot', 'repeat', 'while', 'color', '...
# 7   loops+if+position  ['fly', 'shoot', 'repeat', 'while', 'color', '...
# 8       loops+if+else  ['fly', 'shoot', 'repeat', 'while', 'color', '...
# 9            complete  ['fly', 'shoot', 'repeat', 'while', 'color', '...

# %% [markdown]
# ## Students

# %%
load_entity('students').head()
# Out:
#     credits                                  seen_instructions
# id
# 1        35  ['env.space-world', 'env.toolbox', 'env.snappi...
# 2         0                                                 []
# 3        39  ['env.space-world', 'env.toolbox', 'env.snappi...
# 4         4  ['env.space-world', 'env.toolbox', 'env.snappi...

# %% [markdown]
# ## Task Sessions

# %%
load_entity('task_sessions').head()
# Out:
#     student  task  solved                        start  \
# id
# 5         1    36   False  2017-11-03T14:18:33.507352Z
# 6         1    21   False  2017-11-03T14:41:10.792866Z
# 7         1    22    True  2017-11-03T15:04:38.763391Z
# 8         1    33    True  2017-11-03T16:24:48.621123Z
# 9         1    12    True  2017-11-03T16:38:50.718301Z
#
#                             end  time_spent
# id
# 5   2017-11-03T14:18:33.507363Z           0
# 6   2017-11-03T15:04:01.947104Z        1371
# 7   2017-11-03T16:08:13.435480Z        3814
# 8   2017-11-03T16:25:02.587917Z          13
# 9   2017-11-03T16:39:09.866528Z          19

# %% [markdown]
# ## Program Snapshots

# %%
snapshots = load_entity('program_snapshots')
snapshots.head(14)
# Out:
#     task_session                         time program granularity  order  \
# id
# 31             6  2017-11-03T15:03:52.665539Z       f        edit      1
# 32             6  2017-11-03T15:04:02.015296Z      fr        edit      2
# 33             7  2017-11-03T15:04:41.870822Z       f        edit      1
# 34             7  2017-11-03T15:04:43.445636Z      ff        edit      2
# 35             7  2017-11-03T16:03:06.944434Z       f        edit      3
# 36             7  2017-11-03T16:04:48.070260Z       f        edit      4
# 37             7  2017-11-03T16:04:49.945154Z       f        edit      5
# 38             7  2017-11-03T16:06:07.973780Z       f        edit      6
# 39             7  2017-11-03T16:06:10.865586Z       f        edit      7
# 40             7  2017-11-03T16:07:35.284635Z       f        edit      8
# 41             7  2017-11-03T16:07:37.450566Z       f   execution      1
# 42             7  2017-11-03T16:08:02.683180Z      ff        edit      9
# 43             7  2017-11-03T16:08:04.182221Z     fff        edit     10
# 44             7  2017-11-03T16:08:13.565203Z     fff   execution      2
#
#    correct  time_from_start  time_delta
# id
# 31     NaN             1361        1361
# 32     NaN             1371          10
# 33     NaN                3           3
# 34     NaN                4           1
# 35     NaN             3508        3504
# 36     NaN             3609         101
# 37     NaN             3611           2
# 38     NaN             3689          78
# 39     NaN             3692           3
# 40     NaN             3776          84
# 41   False             3778        3778
# 42     NaN             3803          27
# 43     NaN             3805           2
# 44    True             3814          36

# %% [markdown]
# * there are 2 granularity levels: `{'edit', 'execution'}`
# * `correct` field is only set for `execution` snapshots
# * `order` and `time_delta` are computed per-granularity
# * `time_delta` = number of seconds from the last snapshot of the same granularity
# * `time_from_start` = number of seconds from the start of the task session

# %% [markdown]
# ## Actions
#
# Actions time series describes all actions we model.
# State of all other entities is given by
# the initial state (static data, such as tasks and levels) and the actions.
# Form most analyses, it's easier to use some derived data (such as task sessions) instead of raw actions.
#
# Actions are semi-structured: there are some common fields (e.g name, time, student, task)
# and an unstructured action-specific dictionary in the `data` column.
#
# Note: Although `task` was decided to be a common field, not all actions have it
# (namely `watch-instruction` don't).
# As a result, there are some NaNs in this column and pandas use floats for them
# (it's not possible to have integers and NaNs in the same array).

# %%
actions = load_entity('actions')
actions[20:30]
# Out:
#             name  student  task                         time  randomness  \
# id
# 65    start-task        1  22.0  2017-11-03T15:04:38.837156Z   846556146
# 66  edit-program        1  22.0  2017-11-03T15:04:41.929466Z   973306676
# 67  edit-program        1  22.0  2017-11-03T15:04:43.504214Z   256778077
# 68  edit-program        1  22.0  2017-11-03T16:03:07.001961Z   809371847
# 69  edit-program        1  22.0  2017-11-03T16:04:48.129308Z   284165005
# 70  edit-program        1  22.0  2017-11-03T16:04:50.003349Z   892026422
# 71  edit-program        1  22.0  2017-11-03T16:06:08.031688Z   273533843
# 72  edit-program        1  22.0  2017-11-03T16:06:10.923623Z   141552777
# 73  edit-program        1  22.0  2017-11-03T16:07:35.343301Z  1039088847
# 74   run-program        1  22.0  2017-11-03T16:07:37.508914Z   867039629
#
#                                                  data
# id
# 65                             {'task_session_id': 7}
# 66             {'program': 'f', 'task_session_id': 7}
# 67            {'program': 'ff', 'task_session_id': 7}
# 68             {'program': 'f', 'task_session_id': 7}
# 69             {'program': 'f', 'task_session_id': 7}
# 70             {'program': 'f', 'task_session_id': 7}
# 71             {'program': 'f', 'task_session_id': 7}
# 72             {'program': 'f', 'task_session_id': 7}
# 73             {'program': 'f', 'task_session_id': 7}
# 74  {'task_session_id': 7, 'program': 'f', 'correc...

# %%
# Currently, there are only 4 types of action:
set(actions.name)
# Out:
# {'edit-program', 'run-program', 'start-task', 'watch-instruction'}
